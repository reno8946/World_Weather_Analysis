# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1c9185c03b56d15ae8863cd6b452e190

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1c9185c03b56d15ae8863cd6b452e190&q=Boston

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description=city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | abu samrah
# Processing Record 4 of Set 1 | namibe
# Processing Record 5 of Set 1 | ambovombe
# Processing Record 6 of Set 1 | bam
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | broken hill
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | san cristobal
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | rabat
# Processing Record 14 of Set 1 | goderich
# Processing Record 15 of Set 1 | saurimo
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | mala tokmachka
# Processing Record 18 of Set 1 | vanimo
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | saint-augustin
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | leshukonskoye
# Processing Record 26 of Set 1 | teguldet
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | benque viejo
# City not found. Skipping...
# Processing Record 29 of Set 1 | hambantota
# Processing Record 30 of Set 1 | panorama
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | adre
# Processing Record 33 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 1 | richards bay
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | verkhnevilyuysk
# Processing Record 37 of Set 1 | kruisfontein
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | hamilton
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | fukue
# Processing Record 42 of Set 1 | chalus
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | prince rupert
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | acapulco
# Processing Record 47 of Set 1 | salinopolis
# Processing Record 48 of Set 1 | luderitz
# Processing Record 49 of Set 1 | bubaque
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | ye
# City not found. Skipping...
# Processing Record 3 of Set 2 | livani
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | bafata
# Processing Record 6 of Set 2 | vanavara
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | koungheul
# Processing Record 9 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | kuito
# Processing Record 18 of Set 2 | alamosa
# Processing Record 19 of Set 2 | birjand
# Processing Record 20 of Set 2 | warren
# Processing Record 21 of Set 2 | shunyi
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | verkhoyansk
# Processing Record 26 of Set 2 | coos bay
# Processing Record 27 of Set 2 | bend
# Processing Record 28 of Set 2 | faya
# Processing Record 29 of Set 2 | paucartambo
# City not found. Skipping...
# Processing Record 30 of Set 2 | touros
# Processing Record 31 of Set 2 | port lincoln
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | khorramabad
# Processing Record 34 of Set 2 | yaring
# Processing Record 35 of Set 2 | gravdal
# Processing Record 36 of Set 2 | rolla
# Processing Record 37 of Set 2 | ilulissat
# Processing Record 38 of Set 2 | pochutla
# Processing Record 39 of Set 2 | shimoda
# Processing Record 40 of Set 2 | pitimbu
# Processing Record 41 of Set 2 | baykit
# Processing Record 42 of Set 2 | juneau
# Processing Record 43 of Set 2 | liaozhong
# Processing Record 44 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | ossora
# Processing Record 48 of Set 2 | vardo
# Processing Record 49 of Set 2 | iracoubo
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | erenhot
# Processing Record 2 of Set 3 | puerto colombia
# Processing Record 3 of Set 3 | gat
# Processing Record 4 of Set 3 | ovruch
# Processing Record 5 of Set 3 | vanersborg
# Processing Record 6 of Set 3 | umm lajj
# Processing Record 7 of Set 3 | port macquarie
# Processing Record 8 of Set 3 | las vegas
# Processing Record 9 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 10 of Set 3 | igrim
# Processing Record 11 of Set 3 | nago
# Processing Record 12 of Set 3 | esperance
# Processing Record 13 of Set 3 | uarini
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | pangody
# Processing Record 16 of Set 3 | aklavik
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | ahipara
# Processing Record 20 of Set 3 | waingapu
# Processing Record 21 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 3 | port hardy
# Processing Record 23 of Set 3 | san jeronimo
# Processing Record 24 of Set 3 | high level
# Processing Record 25 of Set 3 | maniitsoq
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | saint george
# Processing Record 28 of Set 3 | bilibino
# Processing Record 29 of Set 3 | champasak
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | kopyevo
# City not found. Skipping...
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 3 | mbanza-ngungu
# Processing Record 35 of Set 3 | mar del plata
# Processing Record 36 of Set 3 | comodoro rivadavia
# Processing Record 37 of Set 3 | lakhdenpokhya
# Processing Record 38 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | catuday
# Processing Record 40 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 3 | leningradskiy
# Processing Record 43 of Set 3 | huarmey
# Processing Record 44 of Set 3 | deputatskiy
# Processing Record 45 of Set 3 | palu
# Processing Record 46 of Set 3 | ahuimanu
# Processing Record 47 of Set 3 | haines junction
# Processing Record 48 of Set 3 | yar-sale
# Processing Record 49 of Set 3 | kavieng
# Processing Record 50 of Set 3 | buenos aires
# Processing Record 1 of Set 4 | hervey bay
# Processing Record 2 of Set 4 | abnub
# Processing Record 3 of Set 4 | fomboni
# Processing Record 4 of Set 4 | annau
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | kavaratti
# Processing Record 8 of Set 4 | kapaa
# Processing Record 9 of Set 4 | innisfail
# Processing Record 10 of Set 4 | vestmannaeyjar
# Processing Record 11 of Set 4 | vilyuysk
# Processing Record 12 of Set 4 | moose factory
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | marrakesh
# Processing Record 15 of Set 4 | durban
# Processing Record 16 of Set 4 | gejiu
# Processing Record 17 of Set 4 | bambanglipuro
# Processing Record 18 of Set 4 | ribas do rio pardo
# Processing Record 19 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 20 of Set 4 | pisco
# Processing Record 21 of Set 4 | champerico
# Processing Record 22 of Set 4 | okhotsk
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | nova olinda do norte
# Processing Record 25 of Set 4 | lunenburg
# Processing Record 26 of Set 4 | fort nelson
# Processing Record 27 of Set 4 | turukhansk
# Processing Record 28 of Set 4 | conde
# Processing Record 29 of Set 4 | san patricio
# Processing Record 30 of Set 4 | port elizabeth
# Processing Record 31 of Set 4 | sao joao da barra
# Processing Record 32 of Set 4 | nokaneng
# Processing Record 33 of Set 4 | tianpeng
# Processing Record 34 of Set 4 | wewak
# Processing Record 35 of Set 4 | horoatu crasnei
# Processing Record 36 of Set 4 | mincivan
# Processing Record 37 of Set 4 | qaqortoq
# Processing Record 38 of Set 4 | znamenskoye
# Processing Record 39 of Set 4 | tuktoyaktuk
# Processing Record 40 of Set 4 | virginia beach
# Processing Record 41 of Set 4 | miandrivazo
# Processing Record 42 of Set 4 | tadine
# Processing Record 43 of Set 4 | lata
# Processing Record 44 of Set 4 | souillac
# Processing Record 45 of Set 4 | irbeyskoye
# Processing Record 46 of Set 4 | iskateley
# Processing Record 47 of Set 4 | zhezkazgan
# Processing Record 48 of Set 4 | harper
# Processing Record 49 of Set 4 | talnakh
# Processing Record 50 of Set 4 | ende
# Processing Record 1 of Set 5 | tyret pervaya
# Processing Record 2 of Set 5 | grand-lahou
# Processing Record 3 of Set 5 | alofi
# Processing Record 4 of Set 5 | palmer
# Processing Record 5 of Set 5 | yatou
# Processing Record 6 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 5 | chuy
# Processing Record 8 of Set 5 | coihaique
# Processing Record 9 of Set 5 | yamethin
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | yelan
# Processing Record 12 of Set 5 | palaiokhora
# City not found. Skipping...
# Processing Record 13 of Set 5 | puerto escondido
# Processing Record 14 of Set 5 | hagere hiywet
# Processing Record 15 of Set 5 | mayor pablo lagerenza
# Processing Record 16 of Set 5 | victoria
# Processing Record 17 of Set 5 | antofagasta
# Processing Record 18 of Set 5 | gondanglegi
# Processing Record 19 of Set 5 | kenai
# Processing Record 20 of Set 5 | lagoa
# Processing Record 21 of Set 5 | wadi musa
# Processing Record 22 of Set 5 | morristown
# Processing Record 23 of Set 5 | vao
# Processing Record 24 of Set 5 | ust-tsilma
# Processing Record 25 of Set 5 | camopi
# Processing Record 26 of Set 5 | durazno
# Processing Record 27 of Set 5 | gerede
# Processing Record 28 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 5 | burgeo
# Processing Record 30 of Set 5 | ampanihy
# Processing Record 31 of Set 5 | galesong
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | kantunilkin
# Processing Record 34 of Set 5 | tambopata
# Processing Record 35 of Set 5 | bay roberts
# Processing Record 36 of Set 5 | lorengau
# Processing Record 37 of Set 5 | arraial do cabo
# Processing Record 38 of Set 5 | severo-kurilsk
# Processing Record 39 of Set 5 | exeter
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | kidal
# Processing Record 42 of Set 5 | belmonte
# Processing Record 43 of Set 5 | ostrovnoy
# Processing Record 44 of Set 5 | nanortalik
# Processing Record 45 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 5 | ixtapa
# Processing Record 47 of Set 5 | maraba
# Processing Record 48 of Set 5 | marovoay
# Processing Record 49 of Set 5 | koshurnikovo
# Processing Record 50 of Set 5 | sagua la grande
# Processing Record 1 of Set 6 | provideniya
# Processing Record 2 of Set 6 | porto santo
# Processing Record 3 of Set 6 | jacareacanga
# Processing Record 4 of Set 6 | oreanda
# City not found. Skipping...
# Processing Record 5 of Set 6 | canutama
# Processing Record 6 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 6 | hasaki
# Processing Record 8 of Set 6 | aasiaat
# Processing Record 9 of Set 6 | priiskovyy
# Processing Record 10 of Set 6 | half moon bay
# Processing Record 11 of Set 6 | rancho palos verdes
# Processing Record 12 of Set 6 | camacha
# Processing Record 13 of Set 6 | asau
# Processing Record 14 of Set 6 | mushie
# Processing Record 15 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 6 | springbok
# Processing Record 18 of Set 6 | necochea
# Processing Record 19 of Set 6 | sumenep
# Processing Record 20 of Set 6 | tairua
# Processing Record 21 of Set 6 | boras
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | sisimiut
# Processing Record 24 of Set 6 | caxias
# Processing Record 25 of Set 6 | makakilo city
# Processing Record 26 of Set 6 | gazanjyk
# Processing Record 27 of Set 6 | solnechnyy
# Processing Record 28 of Set 6 | chokurdakh
# Processing Record 29 of Set 6 | dudinka
# Processing Record 30 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 6 | taoudenni
# Processing Record 32 of Set 6 | kiunga
# Processing Record 33 of Set 6 | nishihara
# Processing Record 34 of Set 6 | varadero
# Processing Record 35 of Set 6 | solano
# Processing Record 36 of Set 6 | khatanga
# Processing Record 37 of Set 6 | aktau
# Processing Record 38 of Set 6 | jaisalmer
# Processing Record 39 of Set 6 | arlit
# Processing Record 40 of Set 6 | megion
# Processing Record 41 of Set 6 | chimoio
# Processing Record 42 of Set 6 | hithadhoo
# Processing Record 43 of Set 6 | nuevitas
# Processing Record 44 of Set 6 | mana
# Processing Record 45 of Set 6 | matoury
# Processing Record 46 of Set 6 | mount isa
# Processing Record 47 of Set 6 | saint-joseph
# Processing Record 48 of Set 6 | isla mujeres
# Processing Record 49 of Set 6 | avarua
# Processing Record 50 of Set 6 | maningrida
# Processing Record 1 of Set 7 | guerrero negro
# Processing Record 2 of Set 7 | zhigansk
# Processing Record 3 of Set 7 | walvis bay
# Processing Record 4 of Set 7 | miri
# Processing Record 5 of Set 7 | hakkari
# Processing Record 6 of Set 7 | dingli
# Processing Record 7 of Set 7 | urdoma
# Processing Record 8 of Set 7 | araouane
# Processing Record 9 of Set 7 | bambous virieux
# Processing Record 10 of Set 7 | mount gambier
# Processing Record 11 of Set 7 | bulgan
# Processing Record 12 of Set 7 | pangnirtung
# Processing Record 13 of Set 7 | flinders
# Processing Record 14 of Set 7 | mildura
# Processing Record 15 of Set 7 | atbasar
# Processing Record 16 of Set 7 | yulara
# Processing Record 17 of Set 7 | sao jose da coroa grande
# Processing Record 18 of Set 7 | klaksvik
# Processing Record 19 of Set 7 | muli
# Processing Record 20 of Set 7 | lima
# Processing Record 21 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 22 of Set 7 | alta floresta
# Processing Record 23 of Set 7 | timizart
# Processing Record 24 of Set 7 | karratha
# Processing Record 25 of Set 7 | olafsvik
# Processing Record 26 of Set 7 | manavalakurichi
# Processing Record 27 of Set 7 | te anau
# Processing Record 28 of Set 7 | luquillo
# Processing Record 29 of Set 7 | surab
# Processing Record 30 of Set 7 | katherine
# Processing Record 31 of Set 7 | polunochnoye
# Processing Record 32 of Set 7 | trairi
# Processing Record 33 of Set 7 | laizhou
# Processing Record 34 of Set 7 | dwarka
# Processing Record 35 of Set 7 | brae
# Processing Record 36 of Set 7 | college
# Processing Record 37 of Set 7 | bargarh
# Processing Record 38 of Set 7 | mahibadhoo
# Processing Record 39 of Set 7 | atherton
# Processing Record 40 of Set 7 | magistralnyy
# Processing Record 41 of Set 7 | korla
# Processing Record 42 of Set 7 | yinchuan
# Processing Record 43 of Set 7 | tual
# Processing Record 44 of Set 7 | wielun
# Processing Record 45 of Set 7 | halle
# Processing Record 46 of Set 7 | westport
# Processing Record 47 of Set 7 | guymon
# Processing Record 48 of Set 7 | dalvik
# Processing Record 49 of Set 7 | auki
# Processing Record 50 of Set 7 | itoman
# Processing Record 1 of Set 8 | dukat
# Processing Record 2 of Set 8 | devils lake
# Processing Record 3 of Set 8 | bandarbeyla
# Processing Record 4 of Set 8 | saint anthony
# Processing Record 5 of Set 8 | fortuna
# Processing Record 6 of Set 8 | elbistan
# Processing Record 7 of Set 8 | saskylakh
# Processing Record 8 of Set 8 | puerto leguizamo
# Processing Record 9 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 8 | laguna
# Processing Record 11 of Set 8 | podares
# Processing Record 12 of Set 8 | pokosnoye
# Processing Record 13 of Set 8 | northam
# Processing Record 14 of Set 8 | bella vista
# Processing Record 15 of Set 8 | shakawe
# Processing Record 16 of Set 8 | pevek
# Processing Record 17 of Set 8 | arman
# Processing Record 18 of Set 8 | dickinson
# Processing Record 19 of Set 8 | birao
# Processing Record 20 of Set 8 | moro
# Processing Record 21 of Set 8 | harmanli
# Processing Record 22 of Set 8 | grinnell
# Processing Record 23 of Set 8 | zhaocheng
# City not found. Skipping...
# Processing Record 24 of Set 8 | inongo
# Processing Record 25 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 26 of Set 8 | kampong thum
# Processing Record 27 of Set 8 | dongning
# Processing Record 28 of Set 8 | isangel
# Processing Record 29 of Set 8 | ponta delgada
# Processing Record 30 of Set 8 | castro alves
# Processing Record 31 of Set 8 | grindavik
# Processing Record 32 of Set 8 | leh
# Processing Record 33 of Set 8 | sungairaya
# Processing Record 34 of Set 8 | mapiripan
# Processing Record 35 of Set 8 | tiksi
# Processing Record 36 of Set 8 | linares
# Processing Record 37 of Set 8 | mitsamiouli
# Processing Record 38 of Set 8 | san lorenzo
# Processing Record 39 of Set 8 | kaeo
# Processing Record 40 of Set 8 | lugovoy
# Processing Record 41 of Set 8 | tucupita
# Processing Record 42 of Set 8 | thunder bay
# Processing Record 43 of Set 8 | catemaco
# Processing Record 44 of Set 8 | nome
# Processing Record 45 of Set 8 | ambo
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | savinskiy
# Processing Record 48 of Set 8 | shivrajpur
# Processing Record 49 of Set 8 | alice springs
# Processing Record 50 of Set 8 | lianyuan
# Processing Record 1 of Set 9 | grand forks
# Processing Record 2 of Set 9 | pak phanang
# Processing Record 3 of Set 9 | awbari
# Processing Record 4 of Set 9 | los llanos de aridane
# Processing Record 5 of Set 9 | geraldton
# Processing Record 6 of Set 9 | chadiza
# Processing Record 7 of Set 9 | diamantino
# Processing Record 8 of Set 9 | funadhoo
# Processing Record 9 of Set 9 | semnan
# Processing Record 10 of Set 9 | bom jesus da lapa
# Processing Record 11 of Set 9 | nizhnevartovsk
# Processing Record 12 of Set 9 | muisne
# Processing Record 13 of Set 9 | sitka
# Processing Record 14 of Set 9 | dogondoutchi
# Processing Record 15 of Set 9 | visby
# Processing Record 16 of Set 9 | rio grande
# Processing Record 17 of Set 9 | drovyanaya
# Processing Record 18 of Set 9 | benemerito de las americas
# Processing Record 19 of Set 9 | kaitangata
# Processing Record 20 of Set 9 | rio gallegos
# Processing Record 21 of Set 9 | manokwari
# Processing Record 22 of Set 9 | soyo
# Processing Record 23 of Set 9 | namatanai
# Processing Record 24 of Set 9 | kavant
# City not found. Skipping...
# Processing Record 25 of Set 9 | suez
# Processing Record 26 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 9 | manggar
# Processing Record 28 of Set 9 | margate
# Processing Record 29 of Set 9 | ligayan
# Processing Record 30 of Set 9 | copiapo
# Processing Record 31 of Set 9 | emerald
# Processing Record 32 of Set 9 | biloela
# Processing Record 33 of Set 9 | russell
# Processing Record 34 of Set 9 | phuket
# Processing Record 35 of Set 9 | charlestown
# Processing Record 36 of Set 9 | topchikha
# Processing Record 37 of Set 9 | meulaboh
# Processing Record 38 of Set 9 | bosaso
# Processing Record 39 of Set 9 | georgetown
# Processing Record 40 of Set 9 | biasca
# Processing Record 41 of Set 9 | chermoz
# Processing Record 42 of Set 9 | sterling
# Processing Record 43 of Set 9 | bilma
# Processing Record 44 of Set 9 | havelock
# Processing Record 45 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 9 | potgietersrus
# City not found. Skipping...
# Processing Record 47 of Set 9 | rexburg
# Processing Record 48 of Set 9 | nuuk
# Processing Record 49 of Set 9 | lichinga
# Processing Record 50 of Set 9 | axim
# Processing Record 1 of Set 10 | novyy urengoy
# Processing Record 2 of Set 10 | upernavik
# Processing Record 3 of Set 10 | novo oriente
# Processing Record 4 of Set 10 | zemio
# Processing Record 5 of Set 10 | mbandaka
# Processing Record 6 of Set 10 | srednekolymsk
# Processing Record 7 of Set 10 | kamen-rybolov
# Processing Record 8 of Set 10 | kargat
# Processing Record 9 of Set 10 | presidencia roque saenz pena
# Processing Record 10 of Set 10 | alushta
# Processing Record 11 of Set 10 | lingyuan
# Processing Record 12 of Set 10 | tsentralnyy
# City not found. Skipping...
# Processing Record 13 of Set 10 | mandera
# Processing Record 14 of Set 10 | tweed
# Processing Record 15 of Set 10 | goya
# Processing Record 16 of Set 10 | sharqpur
# Processing Record 17 of Set 10 | cascais
# Processing Record 18 of Set 10 | san andres
# Processing Record 19 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 10 | kawalu
# Processing Record 21 of Set 10 | armeria
# Processing Record 22 of Set 10 | langsa
# Processing Record 23 of Set 10 | taraclia
# Processing Record 24 of Set 10 | ancud
# Processing Record 25 of Set 10 | maceio
# Processing Record 26 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 27 of Set 10 | torbay
# Processing Record 28 of Set 10 | atasu
# Processing Record 29 of Set 10 | nhulunbuy
# Processing Record 30 of Set 10 | joshimath
# Processing Record 31 of Set 10 | fairbanks
# Processing Record 32 of Set 10 | marsa matruh
# Processing Record 33 of Set 10 | clyde river
# Processing Record 34 of Set 10 | caravelas
# Processing Record 35 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 36 of Set 10 | whitehorse
# Processing Record 37 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 10 | tateyama
# Processing Record 39 of Set 10 | sinnamary
# Processing Record 40 of Set 10 | muros
# Processing Record 41 of Set 10 | tarko-sale
# Processing Record 42 of Set 10 | lerwick
# Processing Record 43 of Set 10 | hobyo
# Processing Record 44 of Set 10 | shirokiy
# Processing Record 45 of Set 10 | zonguldak
# Processing Record 46 of Set 10 | krasnovka
# Processing Record 47 of Set 10 | sembakung
# Processing Record 48 of Set 10 | tuatapere
# Processing Record 49 of Set 10 | lukoyanov
# Processing Record 50 of Set 10 | abu ghosh
# Processing Record 1 of Set 11 | leopold
# Processing Record 2 of Set 11 | san rafael
# Processing Record 3 of Set 11 | ellisras
# Processing Record 4 of Set 11 | saint-denis
# Processing Record 5 of Set 11 | itarema
# Processing Record 6 of Set 11 | vilhena
# Processing Record 7 of Set 11 | miles city
# Processing Record 8 of Set 11 | oktyabrskoye
# Processing Record 9 of Set 11 | sharan
# Processing Record 10 of Set 11 | kirakira
# Processing Record 11 of Set 11 | santa rosa
# Processing Record 12 of Set 11 | aksarka
# Processing Record 13 of Set 11 | elizabeth city
# Processing Record 14 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 11 | mamallapuram
# Processing Record 16 of Set 11 | ardabil
# Processing Record 17 of Set 11 | hachinohe
# Processing Record 18 of Set 11 | pimentel
# Processing Record 19 of Set 11 | tukrah
# Processing Record 20 of Set 11 | dingle
# Processing Record 21 of Set 11 | byron bay
# Processing Record 22 of Set 11 | suluq
# Processing Record 23 of Set 11 | bonnyville
# Processing Record 24 of Set 11 | lavrentiya
# Processing Record 25 of Set 11 | kuanshan
# City not found. Skipping...
# Processing Record 26 of Set 11 | malindi
# Processing Record 27 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 11 | xai-xai
# Processing Record 30 of Set 11 | bonavista
# Processing Record 31 of Set 11 | canora
# Processing Record 32 of Set 11 | hirara
# Processing Record 33 of Set 11 | santomera
# Processing Record 34 of Set 11 | mangrol
# Processing Record 35 of Set 11 | nauta
# Processing Record 36 of Set 11 | bathsheba
# Processing Record 37 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 11 | uglekamensk
# Processing Record 39 of Set 11 | dongsheng
# Processing Record 40 of Set 11 | atar
# Processing Record 41 of Set 11 | shaartuz
# City not found. Skipping...
# Processing Record 42 of Set 11 | raton
# Processing Record 43 of Set 11 | borger
# Processing Record 44 of Set 11 | chuka
# Processing Record 45 of Set 11 | samarai
# Processing Record 46 of Set 11 | bairiki
# Processing Record 47 of Set 11 | tazovskiy
# Processing Record 48 of Set 11 | sayansk
# Processing Record 49 of Set 11 | sarakhs
# Processing Record 50 of Set 11 | constitucion
# Processing Record 1 of Set 12 | gweta
# Processing Record 2 of Set 12 | grootfontein
# Processing Record 3 of Set 12 | springdale
# Processing Record 4 of Set 12 | urengoy
# Processing Record 5 of Set 12 | batagay
# Processing Record 6 of Set 12 | motihari
# Processing Record 7 of Set 12 | canchungo
# Processing Record 8 of Set 12 | paraibano
# Processing Record 9 of Set 12 | amontada
# Processing Record 10 of Set 12 | yerbogachen
# Processing Record 11 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 12 | beringovskiy
# Processing Record 13 of Set 12 | ler
# Processing Record 14 of Set 12 | yerofey pavlovich
# Processing Record 15 of Set 12 | hays
# Processing Record 16 of Set 12 | erzin
# Processing Record 17 of Set 12 | beloha
# Processing Record 18 of Set 12 | kytlym
# City not found. Skipping...
# Processing Record 19 of Set 12 | bourail
# Processing Record 20 of Set 12 | berbera
# Processing Record 21 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 12 | kozan
# Processing Record 23 of Set 12 | cabo san lucas
# Processing Record 24 of Set 12 | pokhara
# Processing Record 25 of Set 12 | sile
# Processing Record 26 of Set 12 | loubomo
# Processing Record 27 of Set 12 | san quintin
# Processing Record 28 of Set 12 | parabel
# Processing Record 29 of Set 12 | krasnoselkup
# Processing Record 30 of Set 12 | nelson bay
# Processing Record 31 of Set 12 | raudeberg
# Processing Record 32 of Set 12 | adrar
# Processing Record 33 of Set 12 | luau
# Processing Record 34 of Set 12 | ruidoso
# Processing Record 35 of Set 12 | bintulu
# Processing Record 36 of Set 12 | port keats
# Processing Record 37 of Set 12 | havre-saint-pierre
# Processing Record 38 of Set 12 | dzaoudzi
# Processing Record 39 of Set 12 | spasskoye
# Processing Record 40 of Set 12 | monte carmelo
# Processing Record 41 of Set 12 | chissamba
# Processing Record 42 of Set 12 | rundu
# Processing Record 43 of Set 12 | sao raimundo das mangabeiras
# Processing Record 44 of Set 12 | oranjemund
# Processing Record 45 of Set 12 | basoko
# Processing Record 46 of Set 12 | baijiantan
# Processing Record 47 of Set 12 | pontianak
# Processing Record 48 of Set 12 | calabozo
# Processing Record 49 of Set 12 | poum
# Processing Record 50 of Set 12 | dabat
# Processing Record 1 of Set 13 | baoying
# Processing Record 2 of Set 13 | brasy
# Processing Record 3 of Set 13 | tomatlan
# Processing Record 4 of Set 13 | broome
# Processing Record 5 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 6 of Set 13 | iisalmi
# Processing Record 7 of Set 13 | stepanov
# Processing Record 8 of Set 13 | coahuayana
# Processing Record 9 of Set 13 | henties bay
# Processing Record 10 of Set 13 | bertoua
# Processing Record 11 of Set 13 | nizwa
# Processing Record 12 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 13 | santa cruz de tenerife
# Processing Record 14 of Set 13 | ust-katav
# Processing Record 15 of Set 13 | gao
# Processing Record 16 of Set 13 | lac-megantic
# Processing Record 17 of Set 13 | santander
# Processing Record 18 of Set 13 | puerto carreno
# Processing Record 19 of Set 13 | anahuac
# Processing Record 20 of Set 13 | manpur
# Processing Record 21 of Set 13 | tessalit
# Processing Record 22 of Set 13 | sao filipe
# Processing Record 23 of Set 13 | cidreira
# Processing Record 24 of Set 13 | tezu
# Processing Record 25 of Set 13 | ivesti
# Processing Record 26 of Set 13 | shitanjing
# Processing Record 27 of Set 13 | paamiut
# Processing Record 28 of Set 13 | hualmay
# Processing Record 29 of Set 13 | marzuq
# Processing Record 30 of Set 13 | lucapa
# Processing Record 31 of Set 13 | maldonado
# Processing Record 32 of Set 13 | shenjiamen
# Processing Record 33 of Set 13 | hofn
# Processing Record 34 of Set 13 | nyurba
# Processing Record 35 of Set 13 | mfou
# Processing Record 36 of Set 13 | sibolga
# Processing Record 37 of Set 13 | saint-remi
# Processing Record 38 of Set 13 | lahaina
# Processing Record 39 of Set 13 | trang
# Processing Record 40 of Set 13 | vagay
# Processing Record 41 of Set 13 | riosucio
# Processing Record 42 of Set 13 | malihabad
# Processing Record 43 of Set 13 | pacific grove
# Processing Record 44 of Set 13 | nyagan
# Processing Record 45 of Set 13 | cap malheureux
# Processing Record 46 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 13 | black river
# Processing Record 49 of Set 13 | hami
# Processing Record 50 of Set 13 | agira
# Processing Record 1 of Set 14 | sabaudia
# Processing Record 2 of Set 14 | neiafu
# Processing Record 3 of Set 14 | harer
# Processing Record 4 of Set 14 | beipiao
# Processing Record 5 of Set 14 | miyazu
# Processing Record 6 of Set 14 | nenjiang
# Processing Record 7 of Set 14 | muswellbrook
# Processing Record 8 of Set 14 | cizre
# Processing Record 9 of Set 14 | bardiyah
# Processing Record 10 of Set 14 | gornopravdinsk
# Processing Record 11 of Set 14 | panique
# Processing Record 12 of Set 14 | kampot
# Processing Record 13 of Set 14 | inuvik
# Processing Record 14 of Set 14 | hay river
# Processing Record 15 of Set 14 | cayenne
# Processing Record 16 of Set 14 | boysun
# Processing Record 17 of Set 14 | biltine
# Processing Record 18 of Set 14 | orbetello
# Processing Record 19 of Set 14 | maamba
# Processing Record 20 of Set 14 | coquimbo
# Processing Record 21 of Set 14 | faanui
# Processing Record 22 of Set 14 | tucurui
# Processing Record 23 of Set 14 | tiarei
# Processing Record 24 of Set 14 | luangwa
# Processing Record 25 of Set 14 | belaya gora
# Processing Record 26 of Set 14 | jinchang
# Processing Record 27 of Set 14 | vocklabruck
# Processing Record 28 of Set 14 | buala
# Processing Record 29 of Set 14 | jega
# Processing Record 30 of Set 14 | kloulklubed
# Processing Record 31 of Set 14 | anton lizardo
# Processing Record 32 of Set 14 | wanlaweyn
# Processing Record 33 of Set 14 | mandal
# Processing Record 34 of Set 14 | witu
# Processing Record 35 of Set 14 | constanza
# Processing Record 36 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 14 | sokolo
# Processing Record 38 of Set 14 | oriximina
# Processing Record 39 of Set 14 | avera
# Processing Record 40 of Set 14 | san policarpo
# Processing Record 41 of Set 14 | afzalgarh
# Processing Record 42 of Set 14 | myitkyina
# Processing Record 43 of Set 14 | marawi
# Processing Record 44 of Set 14 | abaete
# Processing Record 45 of Set 14 | codajas
# Processing Record 46 of Set 14 | ereymentau
# Processing Record 47 of Set 14 | naron
# Processing Record 48 of Set 14 | naze
# Processing Record 49 of Set 14 | plainview
# Processing Record 50 of Set 14 | amapa
# Processing Record 1 of Set 15 | swellendam
# Processing Record 2 of Set 15 | monrovia
# Processing Record 3 of Set 15 | bogorodskoye
# Processing Record 4 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 15 | port blair
# Processing Record 6 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 15 | khvoynaya
# Processing Record 8 of Set 15 | maloy
# Processing Record 9 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 15 | ushtobe
# Processing Record 11 of Set 15 | acari
# Processing Record 12 of Set 15 | saldanha
# Processing Record 13 of Set 15 | nogliki
# Processing Record 14 of Set 15 | damaturu
# Processing Record 15 of Set 15 | tilichiki
# Processing Record 16 of Set 15 | labuhan
# Processing Record 17 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 15 | yeppoon
# Processing Record 19 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 15 | okha
# Processing Record 21 of Set 15 | wanaraja
# Processing Record 22 of Set 15 | wattegama
# Processing Record 23 of Set 15 | yumen
# Processing Record 24 of Set 15 | surt
# Processing Record 25 of Set 15 | staryy nadym
# Processing Record 26 of Set 15 | odweyne
# Processing Record 27 of Set 15 | homer
# Processing Record 28 of Set 15 | kodinsk
# Processing Record 29 of Set 15 | ayagoz
# Processing Record 30 of Set 15 | fallon
# Processing Record 31 of Set 15 | aswan
# Processing Record 32 of Set 15 | chapais
# Processing Record 33 of Set 15 | montrose
# Processing Record 34 of Set 15 | borlange
# City not found. Skipping...
# Processing Record 35 of Set 15 | omboue
# Processing Record 36 of Set 15 | bismarck
# Processing Record 37 of Set 15 | alyangula
# Processing Record 38 of Set 15 | eidsvoll
# Processing Record 39 of Set 15 | tepecoacuilco
# City not found. Skipping...
# Processing Record 40 of Set 15 | asilah
# Processing Record 41 of Set 15 | katesh
# Processing Record 42 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 43 of Set 15 | bogale
# Processing Record 44 of Set 15 | gimli
# Processing Record 45 of Set 15 | roald
# Processing Record 46 of Set 15 | gannan
# Processing Record 47 of Set 15 | qandala
# Processing Record 48 of Set 15 | kununurra
# Processing Record 49 of Set 15 | vila velha
# Processing Record 50 of Set 15 | maniwaki
# Processing Record 1 of Set 16 | tashla
# Processing Record 2 of Set 16 | quang ngai
# Processing Record 3 of Set 16 | kulhudhuffushi
# Processing Record 4 of Set 16 | farafenni
# Processing Record 5 of Set 16 | sept-iles
# Processing Record 6 of Set 16 | nova russas
# Processing Record 7 of Set 16 | chalmette
# Processing Record 8 of Set 16 | bridgetown
# Processing Record 9 of Set 16 | tambun
# Processing Record 10 of Set 16 | briancon
# Processing Record 11 of Set 16 | pahrump
# Processing Record 12 of Set 16 | portland
# Processing Record 13 of Set 16 | grants pass
# Processing Record 14 of Set 16 | saryshagan
# City not found. Skipping...
# Processing Record 15 of Set 16 | wiarton
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Busselton      AU -33.65  115.33     69.01        62          53
# 1     Hermanus      ZA -34.42   19.23     55.00        85           0
# 2   Abu Samrah      SY  35.30   37.18     86.05        13          78
# 3       Namibe      AO -15.20   12.15     70.50        69           0
# 4    Ambovombe      MG -25.17   46.08     84.02        43           0
# 5          Bam      IR  29.11   58.36     75.07        19           0
# 6        Vaini      TO -21.20 -175.20     75.20        88          40
# 7  Broken Hill      AU -31.95  141.43     75.20        25           0
# 8    Cape Town      ZA -33.93   18.42     64.00        62          20
# 9  Yellowknife      CA  62.46 -114.35     42.80        93          90
#
#    Wind Speed Current Description
# 0        5.99       broken clouds
# 1        1.99           clear sky
# 2       13.91       broken clouds
# 3        4.99           clear sky
# 4        7.09           clear sky
# 5       13.76           clear sky
# 6        8.05    scattered clouds
# 7       11.41           clear sky
# 8       14.99          few clouds
# 9       10.29     overcast clouds

# %%
city_data
# Out:
# [{'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 69.01,
#   'Humidity': 62,
#   'Cloudiness': 53,
#   'Wind Speed': 5.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 55,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Abu Samrah',
#   'Country': 'SY',
#   'Lat': 35.3,
#   'Lng': 37.18,
#   'Max Temp': 86.05,
#   'Humidity': 13,
#   'Cloudiness': 78,
#   'Wind Speed': 13.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.2,
#   'Lng': 12.15,
#   'Max Temp': 70.5,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Ambovombe',
#   'Country': 'MG',
#   'Lat': -25.17,
#   'Lng': 46.08,
#   'Max Temp': 84.02,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 7.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Bam',
#   'Country': 'IR',
#   'Lat': 29.11,
#   'Lng': 58.36,
#   'Max Temp': 75.07,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 13.76,
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.43,
#   'Max Temp': 75.2,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 64,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 64.69,
#   'Humidity': 78,
#   'Cloudiness': 7,
#   'Wind Speed': 1.43,
#   'Current Description': 'clear sky'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 60.01,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Rabat',
#   'Country': 'MA',
#   'Lat': 33.99,
#   'Lng': -6.84,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'mist'},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Lat': 43.75,
#   'Lng': -81.72,
#   'Max Temp': 68,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saurimo',
#   'Country': 'AO',
#   'Lat': -9.66,
#   'Lng': 20.39,
#   'Max Temp': 74.5,
#   'Humidity': 65,
#   'Cloudiness': 49,
#   'Wind Speed': 5.26,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 73.81,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 15.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Mala Tokmachka',
#   'Country': 'UA',
#   'Lat': 47.54,
#   'Lng': 35.89,
#   'Max Temp': 59,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 11.18,
#   'Current Description': 'haze'},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 83.25,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 5.77,
#   'Current Description': 'light rain'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 59,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 23.04,
#   'Current Description': 'light rain'},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 33.93,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 17.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 23.14,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 82,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 52,
#   'Humidity': 72,
#   'Cloudiness': 86,
#   'Wind Speed': 3.94,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 59.7,
#   'Humidity': 73,
#   'Cloudiness': 94,
#   'Wind Speed': 22.28,
#   'Current Description': 'moderate rain'},
#  {'City': 'Leshukonskoye',
#   'Country': 'RU',
#   'Lat': 64.9,
#   'Lng': 45.76,
#   'Max Temp': 49.51,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Teguldet',
#   'Country': 'RU',
#   'Lat': 57.31,
#   'Lng': 88.17,
#   'Max Temp': 34.57,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 80.6,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.12,
#   'Lng': 81.12,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 23.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Panorama',
#   'Country': 'GR',
#   'Lat': 40.59,
#   'Lng': 23.03,
#   'Max Temp': 68,
#   'Humidity': 67,
#   'Cloudiness': 13,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 37.4,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds'},
#  {'City': 'Adre',
#   'Country': 'TD',
#   'Lat': 13.47,
#   'Lng': 22.2,
#   'Max Temp': 84.11,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 5.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Lat': -28.78,
#   'Lng': 32.04,
#   'Max Temp': 68.04,
#   'Humidity': 72,
#   'Cloudiness': 86,
#   'Wind Speed': 20.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 57.67,
#   'Humidity': 66,
#   'Cloudiness': 36,
#   'Wind Speed': 9.78,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Verkhnevilyuysk',
#   'Country': 'RU',
#   'Lat': 63.45,
#   'Lng': 120.32,
#   'Max Temp': 32.61,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 5.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 59,
#   'Humidity': 78,
#   'Cloudiness': 30,
#   'Wind Speed': 5.99,
#   'Current Description': 'light rain'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 66,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 21.92,
#   'Current Description': 'clear sky'},
#  {'City': 'Fukue',
#   'Country': 'JP',
#   'Lat': 32.69,
#   'Lng': 128.84,
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 21.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chalus',
#   'Country': 'IR',
#   'Lat': 36.66,
#   'Lng': 51.42,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 74.95,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.32,
#   'Lng': -130.32,
#   'Max Temp': 48.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 30.33,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 16.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Lat': 16.86,
#   'Lng': -99.89,
#   'Max Temp': 78.6,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salinopolis',
#   'Country': 'BR',
#   'Lat': -0.61,
#   'Lng': -47.36,
#   'Max Temp': 77.32,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 9.04,
#   'Current Description': 'clear sky'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 61.32,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 16.62,
#   'Current Description': 'clear sky'},
#  {'City': 'Bubaque',
#   'Country': 'GW',
#   'Lat': 11.28,
#   'Lng': -15.83,
#   'Max Temp': 80.98,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 9.15,
#   'Current Description': 'clear sky'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 81.27,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 7.36,
#   'Current Description': 'moderate rain'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 57.99,
#   'Humidity': 72,
#   'Cloudiness': 31,
#   'Wind Speed': 6.4,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Livani',
#   'Country': 'LV',
#   'Lat': 56.35,
#   'Lng': 26.18,
#   'Max Temp': 48.07,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 66.99,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bafata',
#   'Country': 'GW',
#   'Lat': 12.17,
#   'Lng': -14.75,
#   'Max Temp': 72.59,
#   'Humidity': 98,
#   'Cloudiness': 17,
#   'Wind Speed': 2.21,
#   'Current Description': 'few clouds'},
#  {'City': 'Vanavara',
#   'Country': 'RU',
#   'Lat': 60.34,
#   'Lng': 102.28,
#   'Max Temp': 30.7,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 39.2,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Koungheul',
#   'Country': 'SN',
#   'Lat': 13.98,
#   'Lng': -14.8,
#   'Max Temp': 76.03,
#   'Humidity': 95,
#   'Cloudiness': 57,
#   'Wind Speed': 7.47,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 57.99,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 62.6,
#   'Humidity': 48,
#   'Cloudiness': 76,
#   'Wind Speed': 16.11,
#   'Current Description': 'light rain'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 54.16,
#   'Humidity': 69,
#   'Cloudiness': 58,
#   'Wind Speed': 5.06,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 57,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 78.37,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 17.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 52,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Kuito',
#   'Country': 'AO',
#   'Lat': -12.38,
#   'Lng': 16.93,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Alamosa',
#   'Country': 'US',
#   'Lat': 37.47,
#   'Lng': -105.87,
#   'Max Temp': 37.4,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Birjand',
#   'Country': 'IR',
#   'Lat': 32.87,
#   'Lng': 59.22,
#   'Max Temp': 62.6,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Warren',
#   'Country': 'US',
#   'Lat': 39.43,
#   'Lng': -84.17,
#   'Max Temp': 66.2,
#   'Humidity': 100,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Shunyi',
#   'Country': 'CN',
#   'Lat': 40.12,
#   'Lng': 116.65,
#   'Max Temp': 73,
#   'Humidity': 53,
#   'Cloudiness': 93,
#   'Wind Speed': 4.47,
#   'Current Description': 'haze'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 35.6,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 54.1,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 12.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 57.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Verkhoyansk',
#   'Country': 'RU',
#   'Lat': 67.54,
#   'Lng': 133.38,
#   'Max Temp': 30.33,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coos Bay',
#   'Country': 'US',
#   'Lat': 43.37,
#   'Lng': -124.22,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'light rain'},
#  {'City': 'Bend',
#   'Country': 'US',
#   'Lat': 44.06,
#   'Lng': -121.32,
#   'Max Temp': 59,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.39,
#   'Lng': 42.45,
#   'Max Temp': 71.6,
#   'Humidity': 11,
#   'Cloudiness': 25,
#   'Wind Speed': 17.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.73,
#   'Lng': 135.87,
#   'Max Temp': 60.51,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 13.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khorramabad',
#   'Country': 'IR',
#   'Lat': 33.49,
#   'Lng': 48.36,
#   'Max Temp': 71.6,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Description': 'moderate rain'},
#  {'City': 'Yaring',
#   'Country': 'TH',
#   'Lat': 6.87,
#   'Lng': 101.37,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Gravdal',
#   'Country': 'NO',
#   'Lat': 68.12,
#   'Lng': 13.5,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rolla',
#   'Country': 'US',
#   'Lat': 37.95,
#   'Lng': -91.77,
#   'Max Temp': 62.6,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': 50,
#   'Humidity': 39,
#   'Cloudiness': 99,
#   'Wind Speed': 25.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pochutla',
#   'Country': 'MX',
#   'Lat': 15.74,
#   'Lng': -96.47,
#   'Max Temp': 77,
#   'Humidity': 85,
#   'Cloudiness': 86,
#   'Wind Speed': 3.67,
#   'Current Description': 'light rain'},
#  {'City': 'Shimoda',
#   'Country': 'JP',
#   'Lat': 34.67,
#   'Lng': 138.95,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 27.51,
#   'Current Description': 'shower rain'},
#  {'City': 'Pitimbu',
#   'Country': 'BR',
#   'Lat': -7.47,
#   'Lng': -34.81,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 79,
#   'Wind Speed': 8.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Baykit',
#   'Country': 'RU',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 32.11,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Juneau',
#   'Country': 'US',
#   'Lat': 58.3,
#   'Lng': -134.42,
#   'Max Temp': 46,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Liaozhong',
#   'Country': 'CN',
#   'Lat': 41.51,
#   'Lng': 122.72,
#   'Max Temp': 73.4,
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 13.42,
#   'Current Description': 'few clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 37.4,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 19.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ossora',
#   'Country': 'RU',
#   'Lat': 59.24,
#   'Lng': 163.07,
#   'Max Temp': 33.62,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 20.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 47.28,
#   'Humidity': 89,
#   'Cloudiness': 13,
#   'Wind Speed': 9.62,
#   'Current Description': 'few clouds'},
#  {'City': 'Iracoubo',
#   'Country': 'GF',
#   'Lat': 5.48,
#   'Lng': -53.2,
#   'Max Temp': 77.95,
#   'Humidity': 87,
#   'Cloudiness': 2,
#   'Wind Speed': 8.1,
#   'Current Description': 'light rain'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Erenhot',
#   'Country': 'CN',
#   'Lat': 43.65,
#   'Lng': 111.98,
#   'Max Temp': 53.33,
#   'Humidity': 40,
#   'Cloudiness': 100,
#   'Wind Speed': 17.16,
#   'Current Description': 'light rain'},
#  {'City': 'Puerto Colombia',
#   'Country': 'CO',
#   'Lat': 10.99,
#   'Lng': -74.95,
#   'Max Temp': 84.2,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gat',
#   'Country': 'IL',
#   'Lat': 31.61,
#   'Lng': 34.76,
#   'Max Temp': 81,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Ovruch',
#   'Country': 'UA',
#   'Lat': 51.32,
#   'Lng': 28.8,
#   'Max Temp': 57.7,
#   'Humidity': 86,
#   'Cloudiness': 86,
#   'Wind Speed': 4.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vanersborg',
#   'Country': 'SE',
#   'Lat': 58.38,
#   'Lng': 12.32,
#   'Max Temp': 46.99,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Current Description': 'moderate rain'},
#  {'City': 'Umm Lajj',
#   'Country': 'SA',
#   'Lat': 25.02,
#   'Lng': 37.27,
#   'Max Temp': 95.02,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 9.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.43,
#   'Lng': 152.92,
#   'Max Temp': 70,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Las Vegas',
#   'Country': 'US',
#   'Lat': 36.17,
#   'Lng': -115.14,
#   'Max Temp': 78.8,
#   'Humidity': 18,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Igrim',
#   'Country': 'RU',
#   'Lat': 63.19,
#   'Lng': 64.42,
#   'Max Temp': 43.56,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nago',
#   'Country': 'JP',
#   'Lat': 26.59,
#   'Lng': 127.98,
#   'Max Temp': 84,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 14.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Uarini',
#   'Country': 'BR',
#   'Lat': -2.99,
#   'Lng': -65.11,
#   'Max Temp': 72.34,
#   'Humidity': 96,
#   'Cloudiness': 98,
#   'Wind Speed': 3.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 20.68,
#   'Humidity': 95,
#   'Cloudiness': 18,
#   'Wind Speed': 3.15,
#   'Current Description': 'few clouds'},
#  {'City': 'Pangody',
#   'Country': 'RU',
#   'Lat': 65.85,
#   'Lng': 74.49,
#   'Max Temp': 34.05,
#   'Humidity': 87,
#   'Cloudiness': 81,
#   'Wind Speed': 8.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 28.4,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'mist'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Description': 'broken clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 82.56,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 13.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.17,
#   'Lng': 173.17,
#   'Max Temp': 57.7,
#   'Humidity': 76,
#   'Cloudiness': 25,
#   'Wind Speed': 13.35,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Waingapu',
#   'Country': 'ID',
#   'Lat': -9.66,
#   'Lng': 120.26,
#   'Max Temp': 88.43,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Current Description': 'moderate rain'},
#  {'City': 'San Jeronimo',
#   'Country': 'PE',
#   'Lat': -11.95,
#   'Lng': -75.28,
#   'Max Temp': 46.27,
#   'Humidity': 66,
#   'Cloudiness': 99,
#   'Wind Speed': 0.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'High Level',
#   'Country': 'CA',
#   'Lat': 58.52,
#   'Lng': -117.14,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'light rain'},
#  {'City': 'Maniitsoq',
#   'Country': 'GL',
#   'Lat': 65.42,
#   'Lng': -52.9,
#   'Max Temp': 44.49,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 20.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 28.4,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 32.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 71.6,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 20.17,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 2.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Champasak',
#   'Country': 'LA',
#   'Lat': 14.75,
#   'Lng': 106,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 19.4,
#   'Humidity': 92,
#   'Cloudiness': 40,
#   'Wind Speed': 0.98,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mbanza-Ngungu',
#   'Country': 'CD',
#   'Lat': -5.25,
#   'Lng': 14.87,
#   'Max Temp': 72.93,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 37.99,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Comodoro Rivadavia',
#   'Country': 'AR',
#   'Lat': -45.87,
#   'Lng': -67.5,
#   'Max Temp': 55.4,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 19.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Lakhdenpokhya',
#   'Country': 'RU',
#   'Lat': 61.52,
#   'Lng': 30.2,
#   'Max Temp': 52,
#   'Humidity': 78,
#   'Cloudiness': 2,
#   'Wind Speed': 10.49,
#   'Current Description': 'clear sky'},
#  {'City': 'Catuday',
#   'Country': 'PH',
#   'Lat': 16.29,
#   'Lng': 119.81,
#   'Max Temp': 83.19,
#   'Humidity': 76,
#   'Cloudiness': 92,
#   'Wind Speed': 6.51,
#   'Current Description': 'light rain'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 33.64,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 22.19,
#   'Current Description': 'light rain'},
#  {'City': 'Huarmey',
#   'Country': 'PE',
#   'Lat': -10.07,
#   'Lng': -78.15,
#   'Max Temp': 60.93,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 2.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 19.9,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palu',
#   'Country': 'ID',
#   'Lat': -0.89,
#   'Lng': 119.87,
#   'Max Temp': 80.92,
#   'Humidity': 78,
#   'Cloudiness': 89,
#   'Wind Speed': 3.47,
#   'Current Description': 'light rain'},
#  {'City': 'Ahuimanu',
#   'Country': 'US',
#   'Lat': 21.44,
#   'Lng': -157.84,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Haines Junction',
#   'Country': 'CA',
#   'Lat': 60.75,
#   'Lng': -137.51,
#   'Max Temp': 36.63,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 2.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 33.4,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 13.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 79.47,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 10.49,
#   'Current Description': 'moderate rain'},
#  {'City': 'Buenos Aires',
#   'Country': 'AR',
#   'Lat': -34.61,
#   'Lng': -58.38,
#   'Max Temp': 57,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Hervey Bay',
#   'Country': 'AU',
#   'Lat': -25.3,
#   'Lng': 152.85,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Abnub',
#   'Country': 'EG',
#   'Lat': 27.27,
#   'Lng': 31.15,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Fomboni',
#   'Country': 'KM',
#   'Lat': -12.28,
#   'Lng': 43.74,
#   'Max Temp': 79.14,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 7.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Annau',
#   'Country': 'TM',
#   'Lat': 37.89,
#   'Lng': 58.52,
#   'Max Temp': 53.6,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 52.32,
#   'Humidity': 89,
#   'Cloudiness': 2,
#   'Wind Speed': 6.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Kavaratti',
#   'Country': 'IN',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'haze'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Innisfail',
#   'Country': 'AU',
#   'Lat': -17.53,
#   'Lng': 146.03,
#   'Max Temp': 76.98,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 9.4,
#   'Current Description': 'clear sky'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 44.13,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 16.49,
#   'Current Description': 'clear sky'},
#  {'City': 'Vilyuysk',
#   'Country': 'RU',
#   'Lat': 63.76,
#   'Lng': 121.62,
#   'Max Temp': 32.45,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 5.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Moose Factory',
#   'Country': 'CA',
#   'Lat': 51.26,
#   'Lng': -80.61,
#   'Max Temp': 39.2,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Marrakesh',
#   'Country': 'MA',
#   'Lat': 31.63,
#   'Lng': -8.01,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Durban',
#   'Country': 'ZA',
#   'Lat': -29.86,
#   'Lng': 31.03,
#   'Max Temp': 66.99,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Gejiu',
#   'Country': 'CN',
#   'Lat': 23.31,
#   'Lng': 103.16,
#   'Max Temp': 66,
#   'Humidity': 69,
#   'Cloudiness': 45,
#   'Wind Speed': 3.33,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bambanglipuro',
#   'Country': 'ID',
#   'Lat': -7.95,
#   'Lng': 110.28,
#   'Max Temp': 82.36,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 15.12,
#   'Current Description': 'light rain'},
#  {'City': 'Ribas Do Rio Pardo',
#   'Country': 'BR',
#   'Lat': -20.44,
#   'Lng': -53.76,
#   'Max Temp': 74.46,
#   'Humidity': 69,
#   'Cloudiness': 98,
#   'Wind Speed': 10.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Champerico',
#   'Country': 'GT',
#   'Lat': 14.3,
#   'Lng': -91.92,
#   'Max Temp': 64.99,
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind Speed': 6.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Okhotsk',
#   'Country': 'RU',
#   'Lat': 59.38,
#   'Lng': 143.3,
#   'Max Temp': 41.79,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 1.19,
#   'Current Description': 'clear sky'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 35.6,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nova Olinda Do Norte',
#   'Country': 'BR',
#   'Lat': -3.89,
#   'Lng': -59.09,
#   'Max Temp': 74.64,
#   'Humidity': 70,
#   'Cloudiness': 44,
#   'Wind Speed': 1.12,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lunenburg',
#   'Country': 'CA',
#   'Lat': 44.38,
#   'Lng': -64.32,
#   'Max Temp': 48.99,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fort Nelson',
#   'Country': 'CA',
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Max Temp': 39.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Turukhansk',
#   'Country': 'RU',
#   'Lat': 65.82,
#   'Lng': 87.98,
#   'Max Temp': 25.03,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Conde',
#   'Country': 'BR',
#   'Lat': -7.26,
#   'Lng': -34.91,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 60,
#   'Wind Speed': 6.89,
#   'Current Description': 'broken clouds'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.02,
#   'Lng': -97.52,
#   'Max Temp': 79,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 72.01,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.14,
#   'Current Description': 'moderate rain'},
#  {'City': 'Nokaneng',
#   'Country': 'BW',
#   'Lat': -19.67,
#   'Lng': 22.27,
#   'Max Temp': 85.39,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 11.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Tianpeng',
#   'Country': 'CN',
#   'Lat': 30.99,
#   'Lng': 103.94,
#   'Max Temp': 72,
#   'Humidity': 79,
#   'Cloudiness': 77,
#   'Wind Speed': 3.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Wewak',
#   'Country': 'PG',
#   'Lat': -3.55,
#   'Lng': 143.63,
#   'Max Temp': 80.13,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 12.12,
#   'Current Description': 'light rain'},
#  {'City': 'Horoatu Crasnei',
#   'Country': 'RO',
#   'Lat': 47.13,
#   'Lng': 22.88,
#   'Max Temp': 50,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mincivan',
#   'Country': 'AZ',
#   'Lat': 39.03,
#   'Lng': 46.72,
#   'Max Temp': 64.45,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 3.96,
#   'Current Description': 'clear sky'},
#  {'City': 'Qaqortoq',
#   'Country': 'GL',
#   'Lat': 60.72,
#   'Lng': -46.03,
#   'Max Temp': 48.2,
#   'Humidity': 39,
#   'Cloudiness': 99,
#   'Wind Speed': 24.16,
#   'Current Description': 'light rain'},
#  {'City': 'Znamenskoye',
#   'Country': 'RU',
#   'Lat': 57.13,
#   'Lng': 73.83,
#   'Max Temp': 41.67,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 30.33,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 8.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Virginia Beach',
#   'Country': 'US',
#   'Lat': 36.85,
#   'Lng': -75.98,
#   'Max Temp': 66,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 10.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Miandrivazo',
#   'Country': 'MG',
#   'Lat': -19.52,
#   'Lng': 45.47,
#   'Max Temp': 93.69,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 2.59,
#   'Current Description': 'clear sky'},
#  {'City': 'Tadine',
#   'Country': 'NC',
#   'Lat': -21.55,
#   'Lng': 167.88,
#   'Max Temp': 74.26,
#   'Humidity': 86,
#   'Cloudiness': 31,
#   'Wind Speed': 12.48,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lata',
#   'Country': 'PT',
#   'Lat': 40.16,
#   'Lng': -8.33,
#   'Max Temp': 60.01,
#   'Humidity': 97,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Irbeyskoye',
#   'Country': 'RU',
#   'Lat': 55.64,
#   'Lng': 95.45,
#   'Max Temp': 36,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 16.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iskateley',
#   'Country': 'RU',
#   'Lat': 67.68,
#   'Lng': 53.15,
#   'Max Temp': 46.36,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 7.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhezkazgan',
#   'Country': 'KZ',
#   'Lat': 47.8,
#   'Lng': 67.71,
#   'Max Temp': 46.72,
#   'Humidity': 47,
#   'Cloudiness': 14,
#   'Wind Speed': 2.73,
#   'Current Description': 'few clouds'},
#  {'City': 'Harper',
#   'Country': 'LR',
#   'Lat': 4.38,
#   'Lng': -7.72,
#   'Max Temp': 76.62,
#   'Humidity': 89,
#   'Cloudiness': 38,
#   'Wind Speed': 6.31,
#   'Current Description': 'light rain'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 6.71,
#   'Current Description': 'light snow'},
#  {'City': 'Ende',
#   'Country': 'ID',
#   'Lat': -8.84,
#   'Lng': 121.66,
#   'Max Temp': 86.65,
#   'Humidity': 58,
#   'Cloudiness': 92,
#   'Wind Speed': 4.47,
#   'Current Description': 'light rain'},
#  {'City': 'Tyret Pervaya',
#   'Country': 'RU',
#   'Lat': 53.67,
#   'Lng': 102.31,
#   'Max Temp': 37.42,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 6.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Grand-Lahou',
#   'Country': 'CI',
#   'Lat': 5.14,
#   'Lng': -5.02,
#   'Max Temp': 75.85,
#   'Humidity': 89,
#   'Cloudiness': 42,
#   'Wind Speed': 6.98,
#   'Current Description': 'light rain'},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 73.4,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 57,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Yatou',
#   'Country': 'CN',
#   'Lat': 37.15,
#   'Lng': 122.38,
#   'Max Temp': 67.86,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 44.35,
#   'Humidity': 90,
#   'Cloudiness': 2,
#   'Wind Speed': 7.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Coihaique',
#   'Country': 'CL',
#   'Lat': -45.58,
#   'Lng': -72.07,
#   'Max Temp': 40.41,
#   'Humidity': 86,
#   'Cloudiness': 61,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yamethin',
#   'Country': 'MM',
#   'Lat': 20.43,
#   'Lng': 96.15,
#   'Max Temp': 90.93,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 5.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 50.99,
#   'Humidity': 86,
#   'Cloudiness': 62,
#   'Wind Speed': 13.13,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yelan',
#   'Country': 'RU',
#   'Lat': 50.95,
#   'Lng': 43.74,
#   'Max Temp': 56.5,
#   'Humidity': 40,
#   'Cloudiness': 82,
#   'Wind Speed': 15.7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Escondido',
#   'Country': 'MX',
#   'Lat': 15.85,
#   'Lng': -97.07,
#   'Max Temp': 78.55,
#   'Humidity': 77,
#   'Cloudiness': 49,
#   'Wind Speed': 4.27,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hagere Hiywet',
#   'Country': 'ET',
#   'Lat': 8.98,
#   'Lng': 37.85,
#   'Max Temp': 68.22,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 7.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Mayor Pablo Lagerenza',
#   'Country': 'PY',
#   'Lat': -19.93,
#   'Lng': -60.77,
#   'Max Temp': 77.63,
#   'Humidity': 47,
#   'Cloudiness': 10,
#   'Wind Speed': 7.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 82,
#   'Humidity': 54,
#   'Cloudiness': 7,
#   'Wind Speed': 8.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Antofagasta',
#   'Country': 'CL',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 59,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gondanglegi',
#   'Country': 'ID',
#   'Lat': -7.75,
#   'Lng': 112.01,
#   'Max Temp': 89.17,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 16.53,
#   'Current Description': 'moderate rain'},
#  {'City': 'Kenai',
#   'Country': 'US',
#   'Lat': 60.55,
#   'Lng': -151.26,
#   'Max Temp': 41,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 70.23,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 7.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Wadi Musa',
#   'Country': 'JO',
#   'Lat': 30.32,
#   'Lng': 35.48,
#   'Max Temp': 82.85,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 5.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Morristown',
#   'Country': 'US',
#   'Lat': 36.21,
#   'Lng': -83.29,
#   'Max Temp': 64,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.73,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 73.08,
#   'Humidity': 87,
#   'Cloudiness': 9,
#   'Wind Speed': 18.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Ust-Tsilma',
#   'Country': 'RU',
#   'Lat': 65.44,
#   'Lng': 52.15,
#   'Max Temp': 48.15,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Camopi',
#   'Country': 'GF',
#   'Lat': 3.17,
#   'Lng': -52.32,
#   'Max Temp': 70.5,
#   'Humidity': 97,
#   'Cloudiness': 26,
#   'Wind Speed': 1.25,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Durazno',
#   'Country': 'UY',
#   'Lat': -33.41,
#   'Lng': -56.5,
#   'Max Temp': 43.43,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 4.65,
#   'Current Description': 'clear sky'},
#  {'City': 'Gerede',
#   'Country': 'TR',
#   'Lat': 40.8,
#   'Lng': 32.2,
#   'Max Temp': 55.65,
#   'Humidity': 76,
#   'Cloudiness': 18,
#   'Wind Speed': 4.63,
#   'Current Description': 'light rain'},
#  {'City': 'Burgeo',
#   'Country': 'CA',
#   'Lat': 47.62,
#   'Lng': -57.62,
#   'Max Temp': 41.22,
#   'Humidity': 68,
#   'Cloudiness': 54,
#   'Wind Speed': 23.33,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ampanihy',
#   'Country': 'MG',
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp': 91.42,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Galesong',
#   'Country': 'ID',
#   'Lat': -5.32,
#   'Lng': 119.37,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 48.2,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 24.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kantunilkin',
#   'Country': 'MX',
#   'Lat': 21.09,
#   'Lng': -87.45,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tambopata',
#   'Country': 'PE',
#   'Lat': -12.73,
#   'Lng': -69.18,
#   'Max Temp': 80.29,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bay Roberts',
#   'Country': 'CA',
#   'Lat': 47.6,
#   'Lng': -53.26,
#   'Max Temp': 44.01,
#   'Humidity': 62,
#   'Cloudiness': 58,
#   'Wind Speed': 20.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.02,
#   'Lng': 147.27,
#   'Max Temp': 76.46,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Current Description': 'moderate rain'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 71.67,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 20.36,
#   'Current Description': 'light rain'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 47.12,
#   'Humidity': 76,
#   'Cloudiness': 4,
#   'Wind Speed': 14.83,
#   'Current Description': 'clear sky'},
#  {'City': 'Exeter',
#   'Country': 'GB',
#   'Lat': 50.72,
#   'Lng': -3.53,
#   'Max Temp': 43,
#   'Humidity': 96,
#   'Cloudiness': 0,
#   'Wind Speed': 8.9,
#   'Current Description': 'clear sky'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 37.4,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'light rain'},
#  {'City': 'Kidal',
#   'Country': 'ML',
#   'Lat': 18.44,
#   'Lng': 1.41,
#   'Max Temp': 85.46,
#   'Humidity': 14,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belmonte',
#   'Country': 'BR',
#   'Lat': -15.86,
#   'Lng': -38.88,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 49.39,
#   'Humidity': 83,
#   'Cloudiness': 88,
#   'Wind Speed': 15.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 44.02,
#   'Humidity': 75,
#   'Cloudiness': 91,
#   'Wind Speed': 24.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 81,
#   'Humidity': 94,
#   'Cloudiness': 86,
#   'Wind Speed': 2.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maraba',
#   'Country': 'BR',
#   'Lat': -5.37,
#   'Lng': -49.12,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 3.36,
#   'Current Description': 'moderate rain'},
#  {'City': 'Marovoay',
#   'Country': 'MG',
#   'Lat': -16.1,
#   'Lng': 46.63,
#   'Max Temp': 89.6,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Current Description': 'few clouds'},
#  {'City': 'Koshurnikovo',
#   'Country': 'RU',
#   'Lat': 54.17,
#   'Lng': 93.3,
#   'Max Temp': 29.57,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 10.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sagua La Grande',
#   'Country': 'CU',
#   'Lat': 22.81,
#   'Lng': -80.08,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 39.63,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Porto Santo',
#   'Country': 'PT',
#   'Lat': 33.07,
#   'Lng': -16.34,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jacareacanga',
#   'Country': 'BR',
#   'Lat': -6.22,
#   'Lng': -57.75,
#   'Max Temp': 76.93,
#   'Humidity': 66,
#   'Cloudiness': 97,
#   'Wind Speed': 0.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Canutama',
#   'Country': 'BR',
#   'Lat': -6.53,
#   'Lng': -64.38,
#   'Max Temp': 75.27,
#   'Humidity': 75,
#   'Cloudiness': 7,
#   'Wind Speed': 0.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Aasiaat',
#   'Country': 'GL',
#   'Lat': 68.71,
#   'Lng': -52.87,
#   'Max Temp': 41.31,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 22.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Priiskovyy',
#   'Country': 'RU',
#   'Lat': 51.93,
#   'Lng': 116.63,
#   'Max Temp': 45.81,
#   'Humidity': 58,
#   'Cloudiness': 95,
#   'Wind Speed': 6.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.46,
#   'Lng': -122.43,
#   'Max Temp': 61,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Rancho Palos Verdes',
#   'Country': 'US',
#   'Lat': 33.74,
#   'Lng': -118.39,
#   'Max Temp': 66.99,
#   'Humidity': 86,
#   'Cloudiness': 58,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Camacha',
#   'Country': 'PT',
#   'Lat': 33.08,
#   'Lng': -16.33,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.43,
#   'Lng': 26.4,
#   'Max Temp': 57.99,
#   'Humidity': 90,
#   'Cloudiness': 93,
#   'Wind Speed': 2.62,
#   'Current Description': 'light rain'},
#  {'City': 'Mushie',
#   'Country': 'CD',
#   'Lat': -3.02,
#   'Lng': 16.9,
#   'Max Temp': 77.85,
#   'Humidity': 84,
#   'Cloudiness': 3,
#   'Wind Speed': 4.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Springbok',
#   'Country': 'ZA',
#   'Lat': -29.66,
#   'Lng': 17.89,
#   'Max Temp': 51.37,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 17.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Lat': -38.55,
#   'Lng': -58.74,
#   'Max Temp': 41.56,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 8.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Sumenep',
#   'Country': 'ID',
#   'Lat': -7.02,
#   'Lng': 113.87,
#   'Max Temp': 86.94,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15,
#   'Current Description': 'moderate rain'},
#  {'City': 'Tairua',
#   'Country': 'NZ',
#   'Lat': -37.02,
#   'Lng': 175.85,
#   'Max Temp': 59,
#   'Humidity': 67,
# ...
#   'Lat': -15.62,
#   'Lng': 30.42,
#   'Max Temp': 93.13,
#   'Humidity': 37,
#   'Cloudiness': 92,
#   'Wind Speed': 3.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belaya Gora',
#   'Country': 'RU',
#   'Lat': 68.53,
#   'Lng': 146.42,
#   'Max Temp': 27.93,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 5.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jinchang',
#   'Country': 'CN',
#   'Lat': 38.5,
#   'Lng': 102.17,
#   'Max Temp': 55.69,
#   'Humidity': 34,
#   'Cloudiness': 61,
#   'Wind Speed': 27.81,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vocklabruck',
#   'Country': 'AT',
#   'Lat': 48.02,
#   'Lng': 13.65,
#   'Max Temp': 52,
#   'Humidity': 89,
#   'Cloudiness': 17,
#   'Wind Speed': 4.56,
#   'Current Description': 'few clouds'},
#  {'City': 'Buala',
#   'Country': 'SB',
#   'Lat': -8.14,
#   'Lng': 159.59,
#   'Max Temp': 82.78,
#   'Humidity': 78,
#   'Cloudiness': 61,
#   'Wind Speed': 10.94,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jega',
#   'Country': 'NG',
#   'Lat': 12.22,
#   'Lng': 4.38,
#   'Max Temp': 78.75,
#   'Humidity': 69,
#   'Cloudiness': 74,
#   'Wind Speed': 6.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.04,
#   'Lng': 134.26,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'shower rain'},
#  {'City': 'Anton Lizardo',
#   'Country': 'MX',
#   'Lat': 19.05,
#   'Lng': -95.98,
#   'Max Temp': 78.01,
#   'Humidity': 70,
#   'Cloudiness': 94,
#   'Wind Speed': 3.49,
#   'Current Description': 'light rain'},
#  {'City': 'Wanlaweyn',
#   'Country': 'SO',
#   'Lat': 2.62,
#   'Lng': 44.89,
#   'Max Temp': 85.95,
#   'Humidity': 57,
#   'Cloudiness': 56,
#   'Wind Speed': 9.4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mandal',
#   'Country': 'IN',
#   'Lat': 25.45,
#   'Lng': 74.57,
#   'Max Temp': 94.03,
#   'Humidity': 16,
#   'Cloudiness': 7,
#   'Wind Speed': 7.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Witu',
#   'Country': 'KE',
#   'Lat': -2.39,
#   'Lng': 40.44,
#   'Max Temp': 84.2,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Constanza',
#   'Country': 'DE',
#   'Lat': 47.66,
#   'Lng': 9.18,
#   'Max Temp': 53.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 1.12,
#   'Current Description': 'moderate rain'},
#  {'City': 'Sokolo',
#   'Country': 'ML',
#   'Lat': 14.73,
#   'Lng': -6.12,
#   'Max Temp': 83.55,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 7.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Oriximina',
#   'Country': 'BR',
#   'Lat': -1.77,
#   'Lng': -55.87,
#   'Max Temp': 80.01,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avera',
#   'Country': 'US',
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Max Temp': 73.4,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Policarpo',
#   'Country': 'PH',
#   'Lat': 12.18,
#   'Lng': 125.51,
#   'Max Temp': 82.4,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Current Description': 'moderate rain'},
#  {'City': 'Afzalgarh',
#   'Country': 'IN',
#   'Lat': 29.4,
#   'Lng': 78.68,
#   'Max Temp': 90.03,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 5.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Myitkyina',
#   'Country': 'MM',
#   'Lat': 25.38,
#   'Lng': 97.4,
#   'Max Temp': 95.58,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 2.68,
#   'Current Description': 'clear sky'},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Lat': 8,
#   'Lng': 124.29,
#   'Max Temp': 77.81,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'light rain'},
#  {'City': 'Abaete',
#   'Country': 'BR',
#   'Lat': -19.16,
#   'Lng': -45.45,
#   'Max Temp': 75.11,
#   'Humidity': 59,
#   'Cloudiness': 32,
#   'Wind Speed': 3.49,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Codajas',
#   'Country': 'BR',
#   'Lat': -3.84,
#   'Lng': -62.06,
#   'Max Temp': 75.02,
#   'Humidity': 75,
#   'Cloudiness': 17,
#   'Wind Speed': 0.96,
#   'Current Description': 'few clouds'},
#  {'City': 'Ereymentau',
#   'Country': 'KZ',
#   'Lat': 51.62,
#   'Lng': 73.1,
#   'Max Temp': 38.08,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 14.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Naron',
#   'Country': 'ES',
#   'Lat': 43.52,
#   'Lng': -8.15,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.37,
#   'Lng': 129.48,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Plainview',
#   'Country': 'US',
#   'Lat': 40.78,
#   'Lng': -73.47,
#   'Max Temp': 62.01,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Amapa',
#   'Country': 'BR',
#   'Lat': 1,
#   'Lng': -52,
#   'Max Temp': 70.02,
#   'Humidity': 98,
#   'Cloudiness': 2,
#   'Wind Speed': 1.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Swellendam',
#   'Country': 'ZA',
#   'Lat': -34.02,
#   'Lng': 20.44,
#   'Max Temp': 62.6,
#   'Humidity': 48,
#   'Cloudiness': 12,
#   'Wind Speed': 16.11,
#   'Current Description': 'light rain'},
#  {'City': 'Monrovia',
#   'Country': 'LR',
#   'Lat': 6.3,
#   'Lng': -10.8,
#   'Max Temp': 77.02,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Current Description': 'moderate rain'},
#  {'City': 'Bogorodskoye',
#   'Country': 'RU',
#   'Lat': 56.55,
#   'Lng': 37.88,
#   'Max Temp': 52.61,
#   'Humidity': 83,
#   'Cloudiness': 93,
#   'Wind Speed': 5.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 82.22,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 17.56,
#   'Current Description': 'light rain'},
#  {'City': 'Khvoynaya',
#   'Country': 'RU',
#   'Lat': 58.9,
#   'Lng': 34.53,
#   'Max Temp': 54.1,
#   'Humidity': 86,
#   'Cloudiness': 95,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maloy',
#   'Country': 'NO',
#   'Lat': 61.94,
#   'Lng': 5.11,
#   'Max Temp': 46.99,
#   'Humidity': 86,
#   'Cloudiness': 94,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ushtobe',
#   'Country': 'KZ',
#   'Lat': 45.25,
#   'Lng': 77.98,
#   'Max Temp': 51.1,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 10.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Acari',
#   'Country': 'PE',
#   'Lat': -15.43,
#   'Lng': -74.62,
#   'Max Temp': 62.8,
#   'Humidity': 68,
#   'Cloudiness': 28,
#   'Wind Speed': 0.58,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 57.2,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Nogliki',
#   'Country': 'RU',
#   'Lat': 51.83,
#   'Lng': 143.17,
#   'Max Temp': 51.82,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 5.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Damaturu',
#   'Country': 'NG',
#   'Lat': 11.75,
#   'Lng': 11.96,
#   'Max Temp': 82.71,
#   'Humidity': 61,
#   'Cloudiness': 5,
#   'Wind Speed': 7.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Tilichiki',
#   'Country': 'RU',
#   'Lat': 60.47,
#   'Lng': 166.1,
#   'Max Temp': 30.51,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 20.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Max Temp': 85.08,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 15.52,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Yeppoon',
#   'Country': 'AU',
#   'Lat': -23.13,
#   'Lng': 150.73,
#   'Max Temp': 86,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Okha',
#   'Country': 'RU',
#   'Lat': 53.57,
#   'Lng': 142.95,
#   'Max Temp': 48.16,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 7.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Wanaraja',
#   'Country': 'ID',
#   'Lat': -7.17,
#   'Lng': 107.98,
#   'Max Temp': 83.64,
#   'Humidity': 54,
#   'Cloudiness': 92,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wattegama',
#   'Country': 'LK',
#   'Lat': 6.8,
#   'Lng': 81.48,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 23.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yumen',
#   'Country': 'CN',
#   'Lat': 40.28,
#   'Lng': 97.2,
#   'Max Temp': 53.62,
#   'Humidity': 36,
#   'Cloudiness': 50,
#   'Wind Speed': 14.58,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Surt',
#   'Country': 'LY',
#   'Lat': 31.21,
#   'Lng': 16.59,
#   'Max Temp': 72.48,
#   'Humidity': 70,
#   'Cloudiness': 33,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Staryy Nadym',
#   'Country': 'RU',
#   'Lat': 65.61,
#   'Lng': 72.68,
#   'Max Temp': 34.74,
#   'Humidity': 85,
#   'Cloudiness': 74,
#   'Wind Speed': 13.6,
#   'Current Description': 'broken clouds'},
#  {'City': 'Odweyne',
#   'Country': 'SO',
#   'Lat': 9.41,
#   'Lng': 45.06,
#   'Max Temp': 84.81,
#   'Humidity': 19,
#   'Cloudiness': 7,
#   'Wind Speed': 5.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Homer',
#   'Country': 'US',
#   'Lat': 59.64,
#   'Lng': -151.55,
#   'Max Temp': 42.01,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 3.53,
#   'Current Description': 'few clouds'},
#  {'City': 'Kodinsk',
#   'Country': 'RU',
#   'Lat': 58.69,
#   'Lng': 99.18,
#   'Max Temp': 35.04,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ayagoz',
#   'Country': 'KZ',
#   'Lat': 47.97,
#   'Lng': 80.44,
#   'Max Temp': 42.6,
#   'Humidity': 48,
#   'Cloudiness': 10,
#   'Wind Speed': 6.31,
#   'Current Description': 'clear sky'},
#  {'City': 'Fallon',
#   'Country': 'US',
#   'Lat': 39.47,
#   'Lng': -118.78,
#   'Max Temp': 59,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Aswan',
#   'Country': 'EG',
#   'Lat': 24.09,
#   'Lng': 32.91,
#   'Max Temp': 98.49,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 7.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.78,
#   'Lng': -74.85,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'light rain'},
#  {'City': 'Montrose',
#   'Country': 'US',
#   'Lat': 38.42,
#   'Lng': -108.27,
#   'Max Temp': 57.99,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Omboue',
#   'Country': 'GA',
#   'Lat': -1.57,
#   'Lng': 9.26,
#   'Max Temp': 77.83,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bismarck',
#   'Country': 'US',
#   'Lat': 46.81,
#   'Lng': -100.78,
#   'Max Temp': 46.4,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 4.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Alyangula',
#   'Country': 'AU',
#   'Lat': -13.85,
#   'Lng': 136.42,
#   'Max Temp': 91.4,
#   'Humidity': 41,
#   'Cloudiness': 14,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds'},
#  {'City': 'Eidsvoll',
#   'Country': 'NO',
#   'Lat': 60.33,
#   'Lng': 11.26,
#   'Max Temp': 44.01,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'light rain'},
#  {'City': 'Asilah',
#   'Country': 'MA',
#   'Lat': 35.47,
#   'Lng': -6.03,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 73,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Katesh',
#   'Country': 'TZ',
#   'Lat': -4.52,
#   'Lng': 35.38,
#   'Max Temp': 76.26,
#   'Humidity': 36,
#   'Cloudiness': 43,
#   'Wind Speed': 5.59,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bogale',
#   'Country': 'MM',
#   'Lat': 16.28,
#   'Lng': 95.4,
#   'Max Temp': 83.77,
#   'Humidity': 75,
#   'Cloudiness': 87,
#   'Wind Speed': 13.73,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gimli',
#   'Country': 'CA',
#   'Lat': 50.63,
#   'Lng': -96.99,
#   'Max Temp': 39,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Roald',
#   'Country': 'NO',
#   'Lat': 62.58,
#   'Lng': 6.13,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 98,
#   'Wind Speed': 12.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gannan',
#   'Country': 'CN',
#   'Lat': 47.91,
#   'Lng': 123.5,
#   'Max Temp': 62.55,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 7.43,
#   'Current Description': 'clear sky'},
#  {'City': 'Qandala',
#   'Country': 'SO',
#   'Lat': 11.47,
#   'Lng': 49.87,
#   'Max Temp': 84.74,
#   'Humidity': 41,
#   'Cloudiness': 70,
#   'Wind Speed': 6.69,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Lat': -15.77,
#   'Lng': 128.73,
#   'Max Temp': 98.6,
#   'Humidity': 23,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.33,
#   'Lng': -40.29,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Maniwaki',
#   'Country': 'CA',
#   'Lat': 46.38,
#   'Lng': -75.97,
#   'Max Temp': 49.71,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tashla',
#   'Country': 'RU',
#   'Lat': 51.77,
#   'Lng': 52.74,
#   'Max Temp': 52.54,
#   'Humidity': 37,
#   'Cloudiness': 11,
#   'Wind Speed': 9.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Quang Ngai',
#   'Country': 'VN',
#   'Lat': 15.12,
#   'Lng': 108.8,
#   'Max Temp': 80.69,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Current Description': 'light rain'},
#  {'City': 'Kulhudhuffushi',
#   'Country': 'MV',
#   'Lat': 6.62,
#   'Lng': 73.07,
#   'Max Temp': 82.74,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 13.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Farafenni',
#   'Country': 'GM',
#   'Lat': 13.57,
#   'Lng': -15.6,
#   'Max Temp': 75.4,
#   'Humidity': 96,
#   'Cloudiness': 15,
#   'Wind Speed': 4.79,
#   'Current Description': 'few clouds'},
#  {'City': 'Sept-Iles',
#   'Country': 'CA',
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 35.01,
#   'Humidity': 79,
#   'Cloudiness': 5,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Nova Russas',
#   'Country': 'BR',
#   'Lat': -4.71,
#   'Lng': -40.56,
#   'Max Temp': 67.3,
#   'Humidity': 93,
#   'Cloudiness': 8,
#   'Wind Speed': 3.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Chalmette',
#   'Country': 'US',
#   'Lat': 29.94,
#   'Lng': -89.96,
#   'Max Temp': 79,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 26.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bridgetown',
#   'Country': 'BB',
#   'Lat': 13.1,
#   'Lng': -59.62,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Current Description': 'shower rain'},
#  {'City': 'Tambun',
#   'Country': 'ID',
#   'Lat': -6.26,
#   'Lng': 107.07,
#   'Max Temp': 89.01,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'moderate rain'},
#  {'City': 'Briancon',
#   'Country': 'FR',
#   'Lat': 44.9,
#   'Lng': 6.65,
#   'Max Temp': 51.01,
#   'Humidity': 89,
#   'Cloudiness': 8,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Pahrump',
#   'Country': 'US',
#   'Lat': 36.21,
#   'Lng': -115.98,
#   'Max Temp': 62.01,
#   'Humidity': 26,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Max Temp': 60.01,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'light rain'},
#  {'City': 'Grants Pass',
#   'Country': 'US',
#   'Lat': 42.44,
#   'Lng': -123.33,
#   'Max Temp': 64.4,
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Wiarton',
#   'Country': 'CA',
#   'Lat': 44.74,
#   'Lng': -81.13,
#   'Max Temp': 69.8,
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 23.04,
#   'Current Description': 'scattered clouds'}]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
